# %% [markdown]
# # Generate Text function - takes trigram model, start string and length of output.

# %%
import pickle

# Load the merged trigram model from the file
with open('../task1/merged_trigram_model.pkl', 'rb') as f:
    merged_trigram_model = pickle.load(f)



print(merged_trigram_model)
# Out:
# defaultdict(<class 'int'>, {'ILL': 4379, 'LLU': 394, 'LUS': 524, 'UST': 2279, 'STR': 2661, 'TRA': 2279, 'RAT': 1809, 'ATI': 3047, 'TIO': 3883, 'ION': 5240, 'ONG': 2313, 'NGR': 288, 'GRE': 1699, 'REA': 4192, 'EAT': 2681, 'AT ': 17310, 'T E': 1097, ' EX': 1861, 'EXP': 880, 'XPE': 391, 'PEC': 989, 'ECT': 2014, 'CTA': 178, 'TAT': 738, 'ONS': 2496, 'NS ': 2466, 'S E': 1224, ' ED': 112, 'EDI': 767, 'DIT': 348, 'ITI': 1040, 'ONB': 56, 'NBY': 15, 'BY ': 3106, 'Y C': 1460, ' CH': 2796, 'CHA': 2338, 'HAR': 1797, 'ARL': 736, 'RLE': 264, 'LES': 2797, 'ES ': 9552, 'S D': 1452, ' DI': 3870, 'DIC': 349, 'ICK': 1403, 'CKE': 1126, 'KEN': 696, 'ENS': 981, 'NSC': 259, 'SCO': 530, 'CON': 3013, 'ONT': 2520, 'NTE': 2565, 'TEN': 2191, 'ENT': 7424, 'NTS': 873, 'TS ': 4609, 'S C': 2049, 'HAP': 1412, 'APT': 978, 'PTE': 594, 'TER': 7289, 'ER ': 19646, 'R I': 2459, ' I.': 142, 'I. ': 165, '. C': 316, ' II': 36, 'II.': 113, 'III': 66, ' IV': 277, 'IV.': 26, 'V. ': 36, 'R V': 224, ' V.': 9, ' VI': 794, 'VI.': 25,
# ...
